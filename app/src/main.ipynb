# %% [markdown]
# # ELROND Dataset

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen
from urllib.request import urljoin
from urllib.request import Request
from urllib.parse import urlparse
import os
from pathlib import Path  

url_list = [
    'https://developer.toradex.com',
    'https://docs.u-boot.org/en/latest/index.html',
    'https://docs.kernel.org'
]

# %%
visited_urls = set()
internal_links = []
max_depth = 10  # Set the maximum depth for recursion
count = 0

filepath = Path('../../dataset/checkpoint_links_list.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  

def save_links(links, filename=filepath):
    df = pd.DataFrame(links, columns=["URL"])
    df.to_csv(filepath, index=False)
    print(f"Saved {len(links)} links to {filename}")

# Function to extract and filter internal links
def get_internal_links(base_url, soup):
    internal_links = set()
    for link in soup.find_all('a', href=True):
        href = link.get('href')
        if href.startswith('/'):
            full_url = urljoin(base_url, href)
            internal_links.add(full_url)
        elif href.startswith(base_url):
            internal_links.add(href)
    return internal_links

def scrape_links(url, depth):
    global count
    if depth > max_depth:
        return
    
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            links = get_internal_links(base_url, soup)

            for link in links:
                if link not in visited_urls:
                    visited_urls.add(link)
                    internal_links.append(link)
                    count += 1

                    if count % 100 == 0:
                        save_links(sorted(internal_links))

                    # Recursively scrape the link
                    scrape_links(link, depth + 1)
        else:
            print(f"Failed to retrieve the webpage at {url}. Status code: {response.status_code}")
    except Exception as e:
        print(f"An error occurred while scraping {url}: {e}")

# Start scraping from the base URL
for base_url in url_list:
    scrape_links(base_url, 0)

# Save remaining links if any
if internal_links:
    save_links(internal_links)
# Out:
# Saved 100 links to ../../dataset/checkpoint_links_list.csv
# Saved 200 links to ../../dataset/checkpoint_links_list.csv
# Saved 300 links to ../../dataset/checkpoint_links_list.csv
# Saved 400 links to ../../dataset/checkpoint_links_list.csv
# Saved 500 links to ../../dataset/checkpoint_links_list.csv
# Saved 600 links to ../../dataset/checkpoint_links_list.csv
# Saved 700 links to ../../dataset/checkpoint_links_list.csv
# Saved 800 links to ../../dataset/checkpoint_links_list.csv
# Saved 900 links to ../../dataset/checkpoint_links_list.csv
# Saved 1000 links to ../../dataset/checkpoint_links_list.csv
# Saved 1100 links to ../../dataset/checkpoint_links_list.csv
# Saved 1200 links to ../../dataset/checkpoint_links_list.csv
# Saved 1300 links to ../../dataset/checkpoint_links_list.csv
# Saved 1400 links to ../../dataset/checkpoint_links_list.csv
# Saved 1500 links to ../../dataset/checkpoint_links_list.csv
# Saved 1600 links to ../../dataset/checkpoint_links_list.csv
# Saved 1700 links to ../../dataset/checkpoint_links_list.csv
# Saved 1800 links to ../../dataset/checkpoint_links_list.csv
# Saved 1900 links to ../../dataset/checkpoint_links_list.csv
# Saved 2000 links to ../../dataset/checkpoint_links_list.csv
# Saved 2100 links to ../../dataset/checkpoint_links_list.csv
# Failed to retrieve the webpage at https://docs.u-boot.org/en/v2023.07/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/search/?q=project:u-boot%20. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24363202/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24604525/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/en/v2022.01/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24378057/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24504619/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/downloads/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24581655/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24366410/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24403071/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24507462/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24423874/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24538658/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24311937/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/accounts/login/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24577302/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24619652/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/versions/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24416245/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/projects/u-boot/builds/24432539/. Status code: 404
# Failed to retrieve the webpage at https://docs.u-boot.org/en/v2023.07.01/. Status code: 404
# Saved 2171 links to ../../dataset/checkpoint_links_list.csv
